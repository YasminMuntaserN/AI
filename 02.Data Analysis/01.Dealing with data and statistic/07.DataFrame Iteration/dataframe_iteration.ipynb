# %%
import pandas as pd

# %%
df = pd.read_csv('Students_exams.csv')
df.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
for index , row in df.iterrows():
   print(index , row)
# Out:
# 0 gender           female
# math score           72
# reading score        72
# writing score        74
# Name: 0, dtype: object
# 1 gender           female
# math score           69
# reading score        90
# writing score        88
# Name: 1, dtype: object
# 2 gender           female
# math score           90
# reading score        95
# writing score        93
# Name: 2, dtype: object
# 3 gender           male
# math score         47
# reading score      57
# writing score      44
# Name: 3, dtype: object
# 4 gender           male
# math score         76
# reading score      78
# writing score      75
# Name: 4, dtype: object
# 5 gender           female
# math score           71
# reading score        83
# writing score        78
# Name: 5, dtype: object
# 6 gender           female
# math score           88
# reading score        95
# writing score        92
# Name: 6, dtype: object
# 7 gender           male
# math score         40
# reading score      43
# writing score      39
# ...

# %%
for index , row in df.iterrows():
   print(index , row['gender'])
# Out:
# 0 female
# 1 female
# 2 female
# 3 male
# 4 male
# 5 female
# 6 female
# 7 male
# 8 male
# 9 female
# 10 male
# 11 male
# 12 female
# 13 male
# 14 female
# 15 female
# 16 male
# 17 female
# 18 male
# 19 female
# 20 male
# 21 female
# 22 male
# 23 female
# 24 male
# 25 male
# 26 male
# 27 female
# 28 male
# 29 female
# 30 female
# 31 female
# 32 female
# 33 male
# 34 male
# 35 male
# 36 female
# 37 female
# 38 female
# 39 male
# 40 male
# 41 female
# 42 female
# 43 male
# 44 female
# 45 male
# 46 female
# 47 female
# 48 female
# 49 male
# 50 male
# 51 male
# 52 male
# 53 male
# 54 female
# 55 female
# 56 female
# 57 male
# 58 male
# 59 female
# 60 male
# 61 male
# 62 male
# 63 female
# 64 female
# 65 male
# 66 male
# 67 female
# 68 male
# 69 female
# 70 female
# 71 male
# 72 female
# 73 male
# 74 male
# 75 male
# 76 male
# 77 male
# 78 female
# 79 female
# 80 female
# 81 male
# 82 male
# 83 male
# 84 male
# 85 female
# 86 female
# 87 female
# 88 female
# 89 female
# 90 female
# ...

# %%
for  row in df.itertuples():
   print(index , row)
# Out:
# 999 Pandas(Index=0, gender='female', _2=72, _3=72, _4=74)
# 999 Pandas(Index=1, gender='female', _2=69, _3=90, _4=88)
# 999 Pandas(Index=2, gender='female', _2=90, _3=95, _4=93)
# 999 Pandas(Index=3, gender='male', _2=47, _3=57, _4=44)
# 999 Pandas(Index=4, gender='male', _2=76, _3=78, _4=75)
# 999 Pandas(Index=5, gender='female', _2=71, _3=83, _4=78)
# 999 Pandas(Index=6, gender='female', _2=88, _3=95, _4=92)
# 999 Pandas(Index=7, gender='male', _2=40, _3=43, _4=39)
# 999 Pandas(Index=8, gender='male', _2=64, _3=64, _4=67)
# 999 Pandas(Index=9, gender='female', _2=38, _3=60, _4=50)
# 999 Pandas(Index=10, gender='male', _2=58, _3=54, _4=52)
# 999 Pandas(Index=11, gender='male', _2=40, _3=52, _4=43)
# 999 Pandas(Index=12, gender='female', _2=65, _3=81, _4=73)
# 999 Pandas(Index=13, gender='male', _2=78, _3=72, _4=70)
# 999 Pandas(Index=14, gender='female', _2=50, _3=53, _4=58)
# 999 Pandas(Index=15, gender='female', _2=69, _3=75, _4=78)
# ...

# %%
for  row in df.itertuples():
   print(row.gender)
# Out:
# female
# female
# female
# male
# male
# female
# female
# male
# male
# female
# male
# male
# female
# male
# female
# female
# male
# female
# male
# female
# male
# female
# male
# female
# male
# male
# male
# female
# male
# female
# female
# female
# female
# male
# male
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# male
# female
# female
# female
# male
# male
# male
# male
# male
# female
# female
# female
# male
# male
# female
# male
# male
# male
# female
# female
# male
# male
# female
# male
# female
# female
# male
# female
# male
# male
# male
# male
# male
# female
# female
# female
# male
# male
# male
# male
# female
# female
# female
# female
# female
# female
# male
# male
# male
# female
# male
# male
# female
# female
# female
# male
# male
# female
# male
# male
# female
# female
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# female
# female
# female
# female
# male
# female
# male
# ...

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score'], dtype='object')

# %%
for col in df.columns:
   print(col)
# Out:
# gender
# math score
# reading score
# writing score

# %%
for col in df.columns:
   print(df[col][2])
# Out:
# female
# 90
# 95
# 93

# %%
for  label,col in df.items():
   print(label , col.values)
# Out:
# gender ['female' 'female' 'female' 'male' 'male' 'female' 'female' 'male' 'male'
#  'female' 'male' 'male' 'female' 'male' 'female' 'female' 'male' 'female'
#  'male' 'female' 'male' 'female' 'male' 'female' 'male' 'male' 'male'
#  'female' 'male' 'female' 'female' 'female' 'female' 'male' 'male' 'male'
#  'female' 'female' 'female' 'male' 'male' 'female' 'female' 'male'
#  'female' 'male' 'female' 'female' 'female' 'male' 'male' 'male' 'male'
#  'male' 'female' 'female' 'female' 'male' 'male' 'female' 'male' 'male'
#  'male' 'female' 'female' 'male' 'male' 'female' 'male' 'female' 'female'
#  'male' 'female' 'male' 'male' 'male' 'male' 'male' 'female' 'female'
#  'female' 'male' 'male' 'male' 'male' 'female' 'female' 'female' 'female'
#  'female' 'female' 'male' 'male' 'male' 'female' 'male' 'male' 'female'
#  'female' 'female' 'male' 'male' 'female' 'male' 'male' 'female' 'female'
#  'male' 'female' 'female' 'female' 'male' 'male' 'female' 'female' 'male'
# ...

# %%
for  label,col in df[['gender' , 'writing score']].items():
   print(label , col.values)
# Out:
# gender ['female' 'female' 'female' 'male' 'male' 'female' 'female' 'male' 'male'
#  'female' 'male' 'male' 'female' 'male' 'female' 'female' 'male' 'female'
#  'male' 'female' 'male' 'female' 'male' 'female' 'male' 'male' 'male'
#  'female' 'male' 'female' 'female' 'female' 'female' 'male' 'male' 'male'
#  'female' 'female' 'female' 'male' 'male' 'female' 'female' 'male'
#  'female' 'male' 'female' 'female' 'female' 'male' 'male' 'male' 'male'
#  'male' 'female' 'female' 'female' 'male' 'male' 'female' 'male' 'male'
#  'male' 'female' 'female' 'male' 'male' 'female' 'male' 'female' 'female'
#  'male' 'female' 'male' 'male' 'male' 'male' 'male' 'female' 'female'
#  'female' 'male' 'male' 'male' 'male' 'female' 'female' 'female' 'female'
#  'female' 'female' 'male' 'male' 'male' 'female' 'male' 'male' 'female'
#  'female' 'female' 'male' 'male' 'female' 'male' 'male' 'female' 'female'
#  'male' 'female' 'female' 'female' 'male' 'male' 'female' 'female' 'male'
# ...

# %%
result = df.loc[2:5 , ['gender' , 'writing score']]
print(result)
print("-----------------------")
for index , row in result.iterrows():
   print(index ,row['gender'] , row['writing score'])
# Out:
#    gender  writing score
# 2  female             93
# 3    male             44
# 4    male             75
# 5  female             78
# -----------------------
# 2 female 93
# 3 male 44
# 4 male 75
# 5 female 78

# %%
print(index , row.values)
# Out:
# 5 ['female' 78]

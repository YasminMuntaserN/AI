# %%
import pandas  as pd
df  = pd.read_csv("car_malfunctions.csv")
df
# Out:
#    Age  malfunctions  DaysOff
# 0    5             6       15
# 1   10            10       20
# 2   20            25       50
# 3   25            50      100
# 4   35            75      200
# 5   40            90      240

# %%
import matplotlib.pyplot as plt
ypoints =df["malfunctions"]
plt.plot(ypoints)
plt.show()

# %%
plt.plot(ypoints , marker = '*')
plt.show()

# %%
plt.plot(ypoints , marker = '*' , linestyle='dashed')
plt.show()

# %%
plt.plot(ypoints , color = 'red')
plt.show()

# %%
plt.plot(ypoints , color = 'red' , linewidth = '10')

# %%
y1 =df["malfunctions"]
y2 =df["Age"]

plt.plot(y1 , marker = 'o')
plt.plot(y2 , marker = 'o')

plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
df =pd.read_csv("car_malfunctions_2.csv")
x = df["Name"]
y = df["Malfunctions"]

plt.xlabel("Machine")
plt.ylabel("Failures")

plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()

# %%
plt.barh(x,y,color="red")
plt.show()

# %%
plt.barh(x,y,height=0.8)
plt.show()

# %%
plt.bar(x,y,width=0.8)
plt.show()
